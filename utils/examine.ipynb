# %%
import xarray as xr
file = 'data/OS_Stratus_201104-201804_D_FLTS-1H.nc'
data = xr.load_dataset(file)
data
# Out:
# <xarray.Dataset>
# Dimensions:                      (TIME: 61408, Deployment: 6, strlen4: 4,
#                                   strlen18: 18, strlen21: 21, strlen23: 23,
#                                   strlen27: 27, strlen33: 33, LATITUDE: 1,
#                                   LONGITUDE: 1)
# Coordinates:
#   * TIME                         (TIME) datetime64[ns] 2011-04-06T21:30:00.00...
#   * Deployment                   (Deployment) int32 11 12 13 14 15 16
#   * strlen4                      (strlen4) int32 -2147483647 ... -2147483647
#   * strlen18                     (strlen18) int32 -2147483647 ... -2147483647
#   * strlen21                     (strlen21) int32 -2147483647 ... -2147483647
#   * strlen23                     (strlen23) int32 -2147483647 ... -2147483647
#   * strlen27                     (strlen27) int32 -2147483647 ... -2147483647
#   * strlen33                     (strlen33) int32 -2147483647 ... -2147483647
# ...

# %%
data.DEP_LAT.mean()
# Out:
# <xarray.DataArray 'DEP_LAT' ()>
# array(-19.68822528)

# %%
data.DEP_LON.mean()
# Out:
# <xarray.DataArray 'DEP_LON' ()>
# array(-85.09493306)

# %%
data.date_set.shape
# Out:
# (6, 21)

# %%
data.date_recovered[0][:]
# Out:
# <xarray.DataArray 'date_recovered' (strlen21: 21)>
# array([b'2', b'0', b'1', b'2', b'-', b'0', b'5', b'-', b'2', b'9', b'T',
#        b'1', b'2', b':', b'3', b'0', b':', b'0', b'0', b'Z', b''],
#       dtype='|S1')
# Coordinates:
#     Deployment  int32 11
#   * strlen21    (strlen21) int32 -2147483647 -2147483647 ... -2147483647
#     DEP_LAT     float64 -19.69
#     DEP_LON     float64 -85.57
